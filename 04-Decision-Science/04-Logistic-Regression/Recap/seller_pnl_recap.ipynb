# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # SELLER P&L ANALYSIS

# %% [markdown]
# The goal of this exercise is to compute, for each `seller_id`:
#
# - The **revenue** it brings (10% of each sales + 80 BRL per month)
# - The **cost** associated with all its bad reviews (1-star = 100 BRL, 2-star = 50, 3-star=40)
# - The resulting **profit** made by Olist for each seller
#
# ❓ Let's not start all again from scratch! Import your seller training set and investigate what you already have.

# %%
from olist.seller import Seller
sellers_df = Seller().get_training_data()

# %% [markdown]
# ❓ What is missing? Write down a strategy to get your missing columns, by re-using as much of  what has already been coded in `seller.py` as possible

# %%
sellers_df.head()
# Out:
#                           seller_id        seller_city seller_state  \
# 0  3442f8959a84dea7ee197c632cb2df15           campinas           SP
# 1  d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu           SP
# 2  ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro           RJ
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo           SP
# 4  51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista           SP
#
#    delay_to_carrier  wait_time     date_first_sale      date_last_sale  \
# 0          0.000000  13.018588 2017-05-05 16:25:11 2017-08-30 12:50:19
# 1          0.000000   9.065716 2017-03-29 02:10:34 2018-06-06 20:15:21
# 2          0.000000   4.042292 2018-07-30 12:44:49 2018-07-30 12:44:49
# 3          0.000000   5.667187 2018-08-03 00:44:08 2018-08-03 00:44:08
# 4          3.353727  35.314861 2017-11-14 12:15:25 2017-11-14 12:15:25
#
#    months_on_olist  n_orders  quantity  quantity_per_order     sales  \
# ...

# %%
# Your pseudo-code

#Getting revenue 
# - Sum sales, then multiply by 10 %
# - months_on_olist and multiply 80BRL per month 

# Apply a function based on the review_score
# Map each orders review score on the orders table, then sum/ group by user_id

# anything less than 2* will cost 100
# if review score >= 2 but < 3 cost 50
# if >= 3 but < 4 will cost 40

#Overall profit 
#Subtract cost of bad review from revenue

# %% [markdown]
# ❓ Update `seller.py` and `order.py` accordingly

# %%
sellers_df['revenue'] = 0.1 * sellers_df['sales'] + 80* sellers_df['months_on_olist']

sellers_df.head()
# Out:
#                           seller_id        seller_city seller_state  \
# 0  3442f8959a84dea7ee197c632cb2df15           campinas           SP
# 1  d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu           SP
# 2  ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro           RJ
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo           SP
# 4  51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista           SP
#
#    delay_to_carrier  wait_time     date_first_sale      date_last_sale  \
# 0          0.000000  13.018588 2017-05-05 16:25:11 2017-08-30 12:50:19
# 1          0.000000   9.065716 2017-03-29 02:10:34 2018-06-06 20:15:21
# 2          0.000000   4.042292 2018-07-30 12:44:49 2018-07-30 12:44:49
# 3          0.000000   5.667187 2018-08-03 00:44:08 2018-08-03 00:44:08
# 4          3.353727  35.314861 2017-11-14 12:15:25 2017-11-14 12:15:25
#
#    months_on_olist  n_orders  quantity  quantity_per_order     sales  \
# ...

# %% [markdown]
# ❓ Compute seller profits

# %%
sellers_df['profit'] = sellers_df['revenue'] - sellers_df['cost_of_reviews']
sellers_df.head()
# Out:
#                           seller_id        seller_city seller_state  \
# 0  3442f8959a84dea7ee197c632cb2df15           campinas           SP
# 1  d1b65fc7debc3361ea86b5f14c68d2e2         mogi guacu           SP
# 2  ce3ad9de960102d0677a81f5d0bb7b2d     rio de janeiro           RJ
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3          sao paulo           SP
# 4  51a04a8a6bdcb23deccc82b0b80742cf  braganca paulista           SP
#
#    delay_to_carrier  wait_time     date_first_sale      date_last_sale  \
# 0          0.000000  13.018588 2017-05-05 16:25:11 2017-08-30 12:50:19
# 1          0.000000   9.065716 2017-03-29 02:10:34 2018-06-06 20:15:21
# 2          0.000000   4.042292 2018-07-30 12:44:49 2018-07-30 12:44:49
# 3          0.000000   5.667187 2018-08-03 00:44:08 2018-08-03 00:44:08
# 4          3.353727  35.314861 2017-11-14 12:15:25 2017-11-14 12:15:25
#
#    months_on_olist  n_orders  quantity  quantity_per_order     sales  \
# ...

# %%
sellers_df.sort_values(by = ['profit'], inplace = True)
sellers_df
# Out:
#                              seller_id       seller_city seller_state  \
# 769   6560211a19b47992c3666cc44a7e94c0         sao paulo           SP
# 2358  4a3ca9315b744ce9f8e9374361493884          ibitinga           SP
# 1357  cc419e0650a3c5ba77189a1882b7556a       santo andre           SP
# 945   ea8482cd71df3c1969d7b9473ff13abc         sao paulo           SP
# 315   8b321bb669392f5163d04c59e235e066         sao paulo           SP
# ...                                ...               ...          ...
# 2830  46dc3b2cc0980fb8ec44634e21d2718e    rio de janeiro           RJ
# 2151  edb1ef5e36e0c8cd84eb3c9b003e486d       teresopolis           RJ
# 534   fa1c13f2614d7b5c4749cbc52fecda94            sumare           SP
# 67    7e93a43ef30c4f03f38b393420bc753a           barueri           SP
# 868   53243585a1d6dc2643021fd1853d8905  lauro de freitas           BA
#
#       delay_to_carrier  wait_time     date_first_sale      date_last_sale  \
# ...

# %%
sellers_df[sellers_df['seller_id'].str.contains('3442f8959a84dea7ee197c632cb2df15')]
# Out:
#                           seller_id seller_city seller_state  \
# 0  3442f8959a84dea7ee197c632cb2df15    campinas           SP
#
#    delay_to_carrier  wait_time     date_first_sale      date_last_sale  \
# 0               0.0  13.018588 2017-05-05 16:25:11 2017-08-30 12:50:19
#
#    months_on_olist  n_orders  quantity  quantity_per_order  sales  \
# 0              4.0         3         3                 1.0  218.7
#
#    share_of_one_stars  share_of_five_stars  review_score  cost_of_reviews  \
# 0            0.333333             0.333333           3.0              140
#
#    revenue  profit
# 0   341.87  201.87

# %%
sellers_df['profit'].sum()
# Out:
# 1167608.4440000001

# %%
sellers_df['profit'][sellers_df['profit']>0].sum()
# Out:
# 1474071.063

# %% [markdown]
# ❓ Sort sellers by profit, and analyse their profitability: conclude on a possible strategy for Olist!
